# %% [markdown]
# # 중간에 test, train dataset (validation 말고) 나누는 것은 엑셀을 건들였음. 구글링 하기 귀찮아서 그냥 엑셀 건듦

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from sklearn.model_selection import train_test_split

# %% [markdown]
# # feature engineering
#
# 열병합 한 상태로 진행

# %%
from os.path import join
df = pd.read_excel('rain_data.xlsx')
df.head()
# Out:
#    홍수사상번호     연  월   일  시간         유입량  데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1  2006  7  10   8  189.100000      6.4           7           7
# 1       1  2006  7  10   9  216.951962      6.3           7           8
# 2       1  2006  7  10  10  251.424419      6.4           7           9
# 3       1  2006  7  10  11  302.812199      7.3           7          10
# 4       1  2006  7  10  12  384.783406      8.2           7          12
#
#    Unnamed: 9  ...  Unnamed: 38  Unnamed: 39  Unnamed: 40  데이터 집단 6  \
# 0           7  ...            8         2.54      122.660       6.4
# 1           7  ...           10         2.53      122.648       7.3
# 2           7  ...           11         2.53      122.636       8.2
# 3           7  ...           14         2.53      122.620      11.3
# 4           8  ...           16         2.53      122.604      14.4
#
#    Unnamed: 42  Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  \
# 0            7            7            8            8         2.54
# 1            7            8           10           10         2.53
# 2            7            9           10           11         2.53
# 3            9           10           15           14         2.53
# 4           12           12           18           16         2.53
#
#    Unnamed: 47
# 0      122.610
# 1      122.600
# 2      122.590
# 3      122.585
# 4      122.575
#
# [5 rows x 48 columns]

# %% [markdown]
# # 연,월,일,시간 을 datetime format 으로 변경
#
# ## 시간 의 경우, datetime 에서 24 를 인식하지 못한다. 비슷한 맥락이므로 -1 을 진행하여 붙힌다

# %%
df['시간'] = df['시간']-1
df.head()
# Out:
#    홍수사상번호     연  월   일  시간         유입량  데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1  2006  7  10   7  189.100000      6.4           7           7
# 1       1  2006  7  10   8  216.951962      6.3           7           8
# 2       1  2006  7  10   9  251.424419      6.4           7           9
# 3       1  2006  7  10  10  302.812199      7.3           7          10
# 4       1  2006  7  10  11  384.783406      8.2           7          12
#
#    Unnamed: 9  ...  Unnamed: 38  Unnamed: 39  Unnamed: 40  데이터 집단 6  \
# 0           7  ...            8         2.54      122.660       6.4
# 1           7  ...           10         2.53      122.648       7.3
# 2           7  ...           11         2.53      122.636       8.2
# 3           7  ...           14         2.53      122.620      11.3
# 4           8  ...           16         2.53      122.604      14.4
#
#    Unnamed: 42  Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  \
# 0            7            7            8            8         2.54
# 1            7            8           10           10         2.53
# 2            7            9           10           11         2.53
# 3            9           10           15           14         2.53
# 4           12           12           18           16         2.53
#
#    Unnamed: 47
# 0      122.610
# 1      122.600
# 2      122.590
# 3      122.585
# 4      122.575
#
# [5 rows x 48 columns]

# %% [markdown]
# ## 연 월 일 시간 을 datetime 으로 한번에 붙힌다.

# %% [markdown]
# ### dateInt 잘 들어갔는지 확인

# %%
df['dateInt']= df['연'].astype(str) + df['월'].astype(str).str.zfill(2)+df['일'].astype(str).str.zfill(2)+df['시간'].astype(str).str.zfill(2)
df['dateInt']
# Out:
# 0       2006071007
# 1       2006071008
# 2       2006071009
# 3       2006071010
# 4       2006071011
#            ...
# 3046    2018070716
# 3047    2018070717
# 3048    2018070718
# 3049    2018070719
# 3050    2018070720
# Name: dateInt, Length: 3051, dtype: object

# %% [markdown]
# ### dateInt 를 datetime format 으로 변경하여 Date 라는 칼럼에 저장

# %%
df['Date'] = pd.to_datetime(df['dateInt'], format="%Y%m%d%H")
df['Date']
# Out:
# 0      2006-07-10 07:00:00
# 1      2006-07-10 08:00:00
# 2      2006-07-10 09:00:00
# 3      2006-07-10 10:00:00
# 4      2006-07-10 11:00:00
#                ...
# 3046   2018-07-07 16:00:00
# 3047   2018-07-07 17:00:00
# 3048   2018-07-07 18:00:00
# 3049   2018-07-07 19:00:00
# 3050   2018-07-07 20:00:00
# Name: Date, Length: 3051, dtype: datetime64[ns]

# %% [markdown]
# ### Date 칼럼이 제일 뒤로 갔으므로 앞으로 당겨서 사용할 것임. insert 사용

# %%
df.insert(4, 'date', value = df['Date'])
df.head()
# Out:
#    홍수사상번호     연  월   일                date  시간         유입량  데이터집단 1  \
# 0       1  2006  7  10 2006-07-10 07:00:00   7  189.100000      6.4
# 1       1  2006  7  10 2006-07-10 08:00:00   8  216.951962      6.3
# 2       1  2006  7  10 2006-07-10 09:00:00   9  251.424419      6.4
# 3       1  2006  7  10 2006-07-10 10:00:00  10  302.812199      7.3
# 4       1  2006  7  10 2006-07-10 11:00:00  11  384.783406      8.2
#
#    Unnamed: 7  Unnamed: 8  ...  Unnamed: 40  데이터 집단 6  Unnamed: 42  \
# 0           7           7  ...      122.660       6.4            7
# 1           7           8  ...      122.648       7.3            7
# 2           7           9  ...      122.636       8.2            7
# 3           7          10  ...      122.620      11.3            9
# 4           7          12  ...      122.604      14.4           12
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0            7            8            8         2.54      122.610
# 1            8           10           10         2.53      122.600
# 2            9           10           11         2.53      122.590
# 3           10           15           14         2.53      122.585
# 4           12           18           16         2.53      122.575
#
#       dateInt                Date
# 0  2006071007 2006-07-10 07:00:00
# 1  2006071008 2006-07-10 08:00:00
# 2  2006071009 2006-07-10 09:00:00
# 3  2006071010 2006-07-10 10:00:00
# 4  2006071011 2006-07-10 11:00:00
#
# [5 rows x 51 columns]

# %% [markdown]
# ### date 라는 칼럼 하나만 사용할 예정이기에, 연,월,일,시간,dateInt, Date 를 drop

# %%
df =df.drop(['연','월','일','시간','dateInt','Date'], axis = 1)
df.head()
# Out:
#    홍수사상번호                date         유입량  데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1 2006-07-10 07:00:00  189.100000      6.4           7           7
# 1       1 2006-07-10 08:00:00  216.951962      6.3           7           8
# 2       1 2006-07-10 09:00:00  251.424419      6.4           7           9
# 3       1 2006-07-10 10:00:00  302.812199      7.3           7          10
# 4       1 2006-07-10 11:00:00  384.783406      8.2           7          12
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 38  \
# 0           7            8         2.54    122.56875  ...            8
# 1           7            8         2.53    122.56250  ...           10
# 2           7            8         2.53    122.55625  ...           11
# 3           7            8         2.53    122.55625  ...           14
# 4           8           10         2.53    122.55625  ...           16
#
#    Unnamed: 39  Unnamed: 40  데이터 집단 6  Unnamed: 42  Unnamed: 43  Unnamed: 44  \
# 0         2.54      122.660       6.4            7            7            8
# 1         2.53      122.648       7.3            7            8           10
# 2         2.53      122.636       8.2            7            9           10
# 3         2.53      122.620      11.3            9           10           15
# 4         2.53      122.604      14.4           12           12           18
#
#    Unnamed: 45  Unnamed: 46  Unnamed: 47
# 0            8         2.54      122.610
# 1           10         2.53      122.600
# 2           11         2.53      122.590
# 3           14         2.53      122.585
# 4           16         2.53      122.575
#
# [5 rows x 45 columns]

# %% [markdown]
# # date, 홍수 사상번호 두개 다 index 로 사용해야될 것 같다고 생각. 나중에 시도해 볼것

# %% [markdown]
# ### date 를 index 로 사용
# #### 해 봤는데, date 로 진행하게 되면 얘가 그래프를 그릴때도, 비어있는 데이터에 대해서 (1,2,3,4,5, 9,10,11,12 월 ) 는 값이 없어서 아예 평균을 내는 현상을 발견함.
# - index 는 date 로 하면 안되는 거 같음.
# - 아... date 데이터 한번 사용해보고 싶었는데... 좀만 더 생각을 해보자.

# %%
# df = df.set_index('date')
# df.head()

# %% [markdown]
# # 데이터 집단 1-6 안에 있는 a-e 데이터를 아예 평균을 내서 새로운 feature 로 저장

# %%
df['avg_A_waterfall']  = (df['Unnamed: 7']  + df['Unnamed: 14'] +df['Unnamed: 21'] +df['Unnamed: 28'] +df['Unnamed: 35'] +df['Unnamed: 42'])/6
df['avg_B_waterfall']  = (df['Unnamed: 8']  + df['Unnamed: 15'] +df['Unnamed: 22'] +df['Unnamed: 29'] +df['Unnamed: 36'] +df['Unnamed: 43'])/6
df['avg_C_waterfall']  = (df['Unnamed: 9']  + df['Unnamed: 16'] +df['Unnamed: 23'] +df['Unnamed: 30'] +df['Unnamed: 37'] +df['Unnamed: 44'])/6
df['avg_D_waterfall']  = (df['Unnamed: 10'] + df['Unnamed: 17'] +df['Unnamed: 24'] +df['Unnamed: 31'] +df['Unnamed: 38'] +df['Unnamed: 45'])/6
df['avg_D_waterlevel'] = (df['Unnamed: 11'] + df['Unnamed: 18'] +df['Unnamed: 25'] +df['Unnamed: 32'] +df['Unnamed: 39'] +df['Unnamed: 46'])/6
df['avg_E_waterlevel'] = (df['Unnamed: 12'] + df['Unnamed: 19'] +df['Unnamed: 26'] +df['Unnamed: 33'] +df['Unnamed: 40'] +df['Unnamed: 47'])/6
df['avg_datagroup'] = (df['데이터집단 1'] + df['데이터집단 2'] +df['데이터집단 3'] +df['데이터 집단 4'] +df['데이터 집단 5'] +df['데이터 집단 6'])/6
df.head()
# Out:
#    홍수사상번호                date         유입량  데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1 2006-07-10 07:00:00  189.100000      6.4           7           7
# 1       1 2006-07-10 08:00:00  216.951962      6.3           7           8
# 2       1 2006-07-10 09:00:00  251.424419      6.4           7           9
# 3       1 2006-07-10 10:00:00  302.812199      7.3           7          10
# 4       1 2006-07-10 11:00:00  384.783406      8.2           7          12
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 45  \
# 0           7            8         2.54    122.56875  ...            8
# 1           7            8         2.53    122.56250  ...           10
# 2           7            8         2.53    122.55625  ...           11
# 3           7            8         2.53    122.55625  ...           14
# 4           8           10         2.53    122.55625  ...           16
#
#    Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0         2.54      122.610         7.000000              7.0
# 1         2.53      122.600         7.000000              8.0
# 2         2.53      122.590         7.000000              9.0
# 3         2.53      122.585         8.000000             10.0
# 4         2.53      122.575        10.166667             12.0
#
#    avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel  \
# 0         7.500000         8.000000              2.54        122.600903
# 1         8.500000         9.000000              2.53        122.597782
# 2         8.666667         9.500000              2.53        122.594661
# 3        11.666667        11.333333              2.53        122.592748
# 4        13.666667        13.166667              2.53        122.587423
#
#    avg_datagroup
# 0       6.366667
# 1       6.833333
# 2       7.600000
# 3       9.600000
# 4      12.333333
#
# [5 rows x 52 columns]

# %% [markdown]
# # scaling 진행 할 것-----> feature engineering 좀만 더 하다가 사용해보자.

# %%
feature_list = ['유입량','데이터집단 1', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','데이터집단 2','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','데이터집단 3','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','데이터 집단 4','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31','Unnamed: 32','Unnamed: 33','데이터 집단 5','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','데이터 집단 6','Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','avg_A_waterfall', 'avg_B_waterfall', 'avg_C_waterfall', 'avg_D_waterfall', 'avg_D_waterlevel', 'avg_E_waterlevel','avg_datagroup']

# %%
for sth in feature_list:
    norm_inflow = (df[sth]-df[sth].min())/(df[sth].max()-df[sth].min())
    df[sth]=norm_inflow
df.head()
# Out:
#    홍수사상번호                date       유입량   데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1 2006-07-10 07:00:00  0.008630  0.019488    0.021277    0.019074
# 1       1 2006-07-10 08:00:00  0.009926  0.019184    0.021277    0.021798
# 2       1 2006-07-10 09:00:00  0.011529  0.019488    0.021277    0.024523
# 3       1 2006-07-10 10:00:00  0.013919  0.022229    0.021277    0.027248
# 4       1 2006-07-10 11:00:00  0.017731  0.024970    0.021277    0.032698
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 45  \
# 0    0.027668     0.030534     0.093930     0.153560  ...     0.030651
# 1    0.027668     0.030534     0.093291     0.153312  ...     0.038314
# 2    0.027668     0.030534     0.093291     0.153064  ...     0.042146
# 3    0.027668     0.030534     0.093291     0.153064  ...     0.053640
# 4    0.031621     0.038168     0.093291     0.153064  ...     0.061303
#
#    Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0     0.093930     0.155313         0.020875         0.019462
# 1     0.093291     0.154916         0.020875         0.022243
# 2     0.093291     0.154518         0.020875         0.025023
# 3     0.093291     0.154320         0.023857         0.027804
# 4     0.093291     0.153923         0.030318         0.033364
#
#    avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel  \
# 0         0.030201         0.030908          0.093930          0.155043
# 1         0.034228         0.034771          0.093291          0.154919
# 2         0.034899         0.036703          0.093291          0.154795
# 3         0.046980         0.043786          0.093291          0.154719
# 4         0.055034         0.050869          0.093291          0.154507
#
#    avg_datagroup
# 0       0.019538
# 1       0.020972
# 2       0.023328
# 3       0.029474
# 4       0.037874
#
# [5 rows x 52 columns]

# %%
plt.figure(figsize = (30,15))
plt.plot(df['avg_D_waterfall'], color = 'black') #강우량
plt.plot(df['avg_D_waterlevel'], color = 'red') #수위

# %%
plt.plot(df['avg_E_waterlevel'])

# %%
plt.figure(figsize = (20,10))
plt.plot(df['유입량'])

# %% [markdown]
# # 만들어 놓은 데이터를 새로운 엑셀 파일로 저장

# %%
df.to_excel(excel_writer='0819_datetime_rain_data.xlsx')
df.head()
# Out:
#    홍수사상번호                date       유입량   데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1 2006-07-10 07:00:00  0.008630  0.019488    0.021277    0.019074
# 1       1 2006-07-10 08:00:00  0.009926  0.019184    0.021277    0.021798
# 2       1 2006-07-10 09:00:00  0.011529  0.019488    0.021277    0.024523
# 3       1 2006-07-10 10:00:00  0.013919  0.022229    0.021277    0.027248
# 4       1 2006-07-10 11:00:00  0.017731  0.024970    0.021277    0.032698
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 45  \
# 0    0.027668     0.030534     0.093930     0.153560  ...     0.030651
# 1    0.027668     0.030534     0.093291     0.153312  ...     0.038314
# 2    0.027668     0.030534     0.093291     0.153064  ...     0.042146
# 3    0.027668     0.030534     0.093291     0.153064  ...     0.053640
# 4    0.031621     0.038168     0.093291     0.153064  ...     0.061303
#
#    Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0     0.093930     0.155313         0.020875         0.019462
# 1     0.093291     0.154916         0.020875         0.022243
# 2     0.093291     0.154518         0.020875         0.025023
# 3     0.093291     0.154320         0.023857         0.027804
# 4     0.093291     0.153923         0.030318         0.033364
#
#    avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel  \
# 0         0.030201         0.030908          0.093930          0.155043
# 1         0.034228         0.034771          0.093291          0.154919
# 2         0.034899         0.036703          0.093291          0.154795
# 3         0.046980         0.043786          0.093291          0.154719
# 4         0.055034         0.050869          0.093291          0.154507
#
#    avg_datagroup
# 0       0.019538
# 1       0.020972
# 2       0.023328
# 3       0.029474
# 4       0.037874
#
# [5 rows x 52 columns]

# %% [markdown]
# # index 설정을 안해서 그런가... 이상하게 값이 저장된다... 맨 앞에 있는 0123456789 가 계속해서 생성된다 저장을 할때마다.
#
# 일단은 저장을 할때 첫 row 는 삭제 하는 식으로 진행하자.

# %% [markdown]
# # train, test dataset 서로 다른 엑셀 파일에 저장하는 것 성공
#
# ## 아니 근데 왜 저장을 할때 마다 새로운 인덱스 column 이 생성되는지 모르겠다.
#
# ### train dataset 에는 1~25 까지의 데이터가 존재 하고
# ### test dataset 에는 26 만 데이터가 존재 하는 상황이다.

# %% [markdown]
# # train data 안에 있을 index는 0-2890 총 2891 개

# %%
df_train = df
df_train = df_train.iloc[:2891]
df_train
# Out:
#       홍수사상번호                date       유입량   데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0          1 2006-07-10 07:00:00  0.008630  0.019488    0.021277    0.019074
# 1          1 2006-07-10 08:00:00  0.009926  0.019184    0.021277    0.021798
# 2          1 2006-07-10 09:00:00  0.011529  0.019488    0.021277    0.024523
# 3          1 2006-07-10 10:00:00  0.013919  0.022229    0.021277    0.027248
# 4          1 2006-07-10 11:00:00  0.017731  0.024970    0.021277    0.032698
# ...      ...                 ...       ...       ...         ...         ...
# 2886      25 2017-07-18 17:00:00  0.023712  0.069378    0.018237    0.000000
# 2887      25 2017-07-18 18:00:00  0.023223  0.025148    0.006079    0.000000
# 2888      25 2017-07-18 19:00:00  0.022716  0.012512    0.003040    0.000000
# 2889      25 2017-07-18 20:00:00  0.022211  0.010309    0.003040    0.000000
# 2890      25 2017-07-18 21:00:00  0.021716  0.010000    0.003040    0.000000
#
#       Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 45  \
# 0       0.027668     0.030534     0.093930     0.153560  ...     0.030651
# 1       0.027668     0.030534     0.093291     0.153312  ...     0.038314
# 2       0.027668     0.030534     0.093291     0.153064  ...     0.042146
# 3       0.027668     0.030534     0.093291     0.153064  ...     0.053640
# 4       0.031621     0.038168     0.093291     0.153064  ...     0.061303
# ...          ...          ...          ...          ...  ...          ...
# 2886    0.003953     0.003817     0.125240     0.733069  ...     0.003831
# 2887    0.003953     0.003817     0.123323     0.733565  ...     0.003831
# 2888    0.003953     0.003817     0.122045     0.733813  ...     0.003831
# 2889    0.003953     0.003817     0.120767     0.734061  ...     0.003831
# 2890    0.003953     0.003817     0.119489     0.734557  ...     0.003831
#
#       Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0        0.093930     0.155313         0.020875         0.019462
# 1        0.093291     0.154916         0.020875         0.022243
# 2        0.093291     0.154518         0.020875         0.025023
# 3        0.093291     0.154320         0.023857         0.027804
# 4        0.093291     0.153923         0.030318         0.033364
# ...           ...          ...              ...              ...
# 2886     0.125240     0.732075         0.017893         0.000000
# 2887     0.123323     0.732671         0.005964         0.000000
# 2888     0.122045     0.733069         0.002982         0.000000
# 2889     0.120767     0.733466         0.002982         0.000000
# 2890     0.119489     0.734062         0.002982         0.000000
#
#       avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel  \
# 0            0.030201         0.030908          0.093930          0.155043
# 1            0.034228         0.034771          0.093291          0.154919
# 2            0.034899         0.036703          0.093291          0.154795
# 3            0.046980         0.043786          0.093291          0.154719
# 4            0.055034         0.050869          0.093291          0.154507
# ...               ...              ...               ...               ...
# 2886         0.004027         0.003863          0.125240          0.732884
# 2887         0.004027         0.003863          0.123323          0.733290
# 2888         0.004027         0.003863          0.122045          0.733622
# 2889         0.004027         0.003863          0.120767          0.734009
# 2890         0.004027         0.003863          0.119489          0.734526
#
#       avg_datagroup
# 0          0.019538
# 1          0.020972
# 2          0.023328
# 3          0.029474
# 4          0.037874
# ...             ...
# 2886       0.024778
# 2887       0.012444
# 2888       0.009199
# 2889       0.008329
# 2890       0.007363
#
# [2891 rows x 52 columns]

# %% [markdown]
# # train_dataset 저장하기

# %%
df_train.to_excel(excel_writer='0819_train.xlsx')
df_train
# Out:
#       홍수사상번호                date       유입량   데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0          1 2006-07-10 07:00:00  0.008630  0.019488    0.021277    0.019074
# 1          1 2006-07-10 08:00:00  0.009926  0.019184    0.021277    0.021798
# 2          1 2006-07-10 09:00:00  0.011529  0.019488    0.021277    0.024523
# 3          1 2006-07-10 10:00:00  0.013919  0.022229    0.021277    0.027248
# 4          1 2006-07-10 11:00:00  0.017731  0.024970    0.021277    0.032698
# ...      ...                 ...       ...       ...         ...         ...
# 2886      25 2017-07-18 17:00:00  0.023712  0.069378    0.018237    0.000000
# 2887      25 2017-07-18 18:00:00  0.023223  0.025148    0.006079    0.000000
# 2888      25 2017-07-18 19:00:00  0.022716  0.012512    0.003040    0.000000
# 2889      25 2017-07-18 20:00:00  0.022211  0.010309    0.003040    0.000000
# 2890      25 2017-07-18 21:00:00  0.021716  0.010000    0.003040    0.000000
#
#       Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 45  \
# 0       0.027668     0.030534     0.093930     0.153560  ...     0.030651
# 1       0.027668     0.030534     0.093291     0.153312  ...     0.038314
# 2       0.027668     0.030534     0.093291     0.153064  ...     0.042146
# 3       0.027668     0.030534     0.093291     0.153064  ...     0.053640
# 4       0.031621     0.038168     0.093291     0.153064  ...     0.061303
# ...          ...          ...          ...          ...  ...          ...
# 2886    0.003953     0.003817     0.125240     0.733069  ...     0.003831
# 2887    0.003953     0.003817     0.123323     0.733565  ...     0.003831
# 2888    0.003953     0.003817     0.122045     0.733813  ...     0.003831
# 2889    0.003953     0.003817     0.120767     0.734061  ...     0.003831
# 2890    0.003953     0.003817     0.119489     0.734557  ...     0.003831
#
#       Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0        0.093930     0.155313         0.020875         0.019462
# 1        0.093291     0.154916         0.020875         0.022243
# 2        0.093291     0.154518         0.020875         0.025023
# 3        0.093291     0.154320         0.023857         0.027804
# 4        0.093291     0.153923         0.030318         0.033364
# ...           ...          ...              ...              ...
# 2886     0.125240     0.732075         0.017893         0.000000
# 2887     0.123323     0.732671         0.005964         0.000000
# 2888     0.122045     0.733069         0.002982         0.000000
# 2889     0.120767     0.733466         0.002982         0.000000
# 2890     0.119489     0.734062         0.002982         0.000000
#
#       avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel  \
# 0            0.030201         0.030908          0.093930          0.155043
# 1            0.034228         0.034771          0.093291          0.154919
# 2            0.034899         0.036703          0.093291          0.154795
# 3            0.046980         0.043786          0.093291          0.154719
# 4            0.055034         0.050869          0.093291          0.154507
# ...               ...              ...               ...               ...
# 2886         0.004027         0.003863          0.125240          0.732884
# 2887         0.004027         0.003863          0.123323          0.733290
# 2888         0.004027         0.003863          0.122045          0.733622
# 2889         0.004027         0.003863          0.120767          0.734009
# 2890         0.004027         0.003863          0.119489          0.734526
#
#       avg_datagroup
# 0          0.019538
# 1          0.020972
# 2          0.023328
# 3          0.029474
# 4          0.037874
# ...             ...
# 2886       0.024778
# 2887       0.012444
# 2888       0.009199
# 2889       0.008329
# 2890       0.007363
#
# [2891 rows x 52 columns]

# %% [markdown]
# # test dataset 만들고 저장하기

# %%
df_test = df
df_test = df_test.iloc[2891:]
df_test.head()
# Out:
#       홍수사상번호                date  유입량   데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 2891      26 2018-07-01 05:00:00  NaN  0.043415    0.097264    0.000000
# 2892      26 2018-07-01 06:00:00  NaN  0.033391    0.060790    0.002725
# 2893      26 2018-07-01 07:00:00  NaN  0.024191    0.033435    0.013624
# 2894      26 2018-07-01 08:00:00  NaN  0.024030    0.009119    0.029973
# 2895      26 2018-07-01 09:00:00  NaN  0.040647    0.012158    0.068120
#
#       Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 45  \
# 2891    0.000000     0.000000     0.054952     0.071198  ...     0.000000
# 2892    0.000000     0.000000     0.054952     0.070950  ...     0.030651
# 2893    0.000000     0.000000     0.054313     0.070702  ...     0.091954
# 2894    0.000000     0.000000     0.054313     0.070454  ...     0.126437
# 2895    0.003953     0.030534     0.054313     0.070454  ...     0.137931
#
#       Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 2891     0.054952     0.072095         0.095427         0.000000
# 2892     0.054952     0.071897         0.061133         0.002780
# 2893     0.054313     0.071698         0.048708         0.013902
# 2894     0.054313     0.071500         0.041252         0.030584
# 2895     0.054313     0.071301         0.049702         0.069509
#
#       avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel  \
# 2891         0.002013         0.000000          0.054952          0.071580
# 2892         0.028188         0.015454          0.054952          0.071455
# 2893         0.038926         0.046362          0.054313          0.071331
# 2894         0.054362         0.068899          0.054313          0.071206
# 2895         0.069128         0.095299          0.054313          0.071178
#
#       avg_datagroup
# 2891       0.023579
# 2892       0.022799
# 2893       0.032402
# 2894       0.048323
# 2895       0.068672
#
# [5 rows x 52 columns]

# %%
df_test.to_excel(excel_writer='0819_test.xlsx')
df_test.head()
# Out:
#       홍수사상번호                date  유입량   데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 2891      26 2018-07-01 05:00:00  NaN  0.043415    0.097264    0.000000
# 2892      26 2018-07-01 06:00:00  NaN  0.033391    0.060790    0.002725
# 2893      26 2018-07-01 07:00:00  NaN  0.024191    0.033435    0.013624
# 2894      26 2018-07-01 08:00:00  NaN  0.024030    0.009119    0.029973
# 2895      26 2018-07-01 09:00:00  NaN  0.040647    0.012158    0.068120
#
#       Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 45  \
# 2891    0.000000     0.000000     0.054952     0.071198  ...     0.000000
# 2892    0.000000     0.000000     0.054952     0.070950  ...     0.030651
# 2893    0.000000     0.000000     0.054313     0.070702  ...     0.091954
# 2894    0.000000     0.000000     0.054313     0.070454  ...     0.126437
# 2895    0.003953     0.030534     0.054313     0.070454  ...     0.137931
#
#       Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 2891     0.054952     0.072095         0.095427         0.000000
# 2892     0.054952     0.071897         0.061133         0.002780
# 2893     0.054313     0.071698         0.048708         0.013902
# 2894     0.054313     0.071500         0.041252         0.030584
# 2895     0.054313     0.071301         0.049702         0.069509
#
#       avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel  \
# 2891         0.002013         0.000000          0.054952          0.071580
# 2892         0.028188         0.015454          0.054952          0.071455
# 2893         0.038926         0.046362          0.054313          0.071331
# 2894         0.054362         0.068899          0.054313          0.071206
# 2895         0.069128         0.095299          0.054313          0.071178
#
#       avg_datagroup
# 2891       0.023579
# 2892       0.022799
# 2893       0.032402
# 2894       0.048323
# 2895       0.068672
#
# [5 rows x 52 columns]

# %% [markdown]
# # 현재 데이터의 총 갯수는 2890 이다. feature 는 51 개

# %%
df = pd.read_excel('0819_train.xlsx')
print(df.shape)
df
# Out:
# (2891, 53)
#       Unnamed: 0  홍수사상번호                date       유입량   데이터집단 1  Unnamed: 7  \
# 0              0       1 2006-07-10 07:00:00  0.008630  0.019488    0.021277
# 1              1       1 2006-07-10 08:00:00  0.009926  0.019184    0.021277
# 2              2       1 2006-07-10 09:00:00  0.011529  0.019488    0.021277
# 3              3       1 2006-07-10 10:00:00  0.013919  0.022229    0.021277
# 4              4       1 2006-07-10 11:00:00  0.017731  0.024970    0.021277
# ...          ...     ...                 ...       ...       ...         ...
# 2886        2886      25 2017-07-18 17:00:00  0.023712  0.069378    0.018237
# 2887        2887      25 2017-07-18 18:00:00  0.023223  0.025148    0.006079
# 2888        2888      25 2017-07-18 19:00:00  0.022716  0.012512    0.003040
# 2889        2889      25 2017-07-18 20:00:00  0.022211  0.010309    0.003040
# 2890        2890      25 2017-07-18 21:00:00  0.021716  0.010000    0.003040
#
#       Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  ...  Unnamed: 45  \
# 0       0.019074    0.027668     0.030534     0.093930  ...     0.030651
# 1       0.021798    0.027668     0.030534     0.093291  ...     0.038314
# 2       0.024523    0.027668     0.030534     0.093291  ...     0.042146
# 3       0.027248    0.027668     0.030534     0.093291  ...     0.053640
# 4       0.032698    0.031621     0.038168     0.093291  ...     0.061303
# ...          ...         ...          ...          ...  ...          ...
# 2886    0.000000    0.003953     0.003817     0.125240  ...     0.003831
# 2887    0.000000    0.003953     0.003817     0.123323  ...     0.003831
# 2888    0.000000    0.003953     0.003817     0.122045  ...     0.003831
# 2889    0.000000    0.003953     0.003817     0.120767  ...     0.003831
# 2890    0.000000    0.003953     0.003817     0.119489  ...     0.003831
#
#       Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0        0.093930     0.155313         0.020875         0.019462
# 1        0.093291     0.154916         0.020875         0.022243
# 2        0.093291     0.154518         0.020875         0.025023
# 3        0.093291     0.154320         0.023857         0.027804
# 4        0.093291     0.153923         0.030318         0.033364
# ...           ...          ...              ...              ...
# 2886     0.125240     0.732075         0.017893         0.000000
# 2887     0.123323     0.732671         0.005964         0.000000
# 2888     0.122045     0.733069         0.002982         0.000000
# 2889     0.120767     0.733466         0.002982         0.000000
# 2890     0.119489     0.734062         0.002982         0.000000
#
#       avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel  \
# 0            0.030201         0.030908          0.093930          0.155043
# 1            0.034228         0.034771          0.093291          0.154919
# 2            0.034899         0.036703          0.093291          0.154795
# 3            0.046980         0.043786          0.093291          0.154719
# 4            0.055034         0.050869          0.093291          0.154507
# ...               ...              ...               ...               ...
# 2886         0.004027         0.003863          0.125240          0.732884
# 2887         0.004027         0.003863          0.123323          0.733290
# 2888         0.004027         0.003863          0.122045          0.733622
# 2889         0.004027         0.003863          0.120767          0.734009
# 2890         0.004027         0.003863          0.119489          0.734526
#
#       avg_datagroup
# 0          0.019538
# 1          0.020972
# 2          0.023328
# 3          0.029474
# 4          0.037874
# ...             ...
# 2886       0.024778
# 2887       0.012444
# 2888       0.009199
# 2889       0.008329
# 2890       0.007363
#
# [2891 rows x 53 columns]

# %% [markdown]
# # date 를 index 로 사용하고자 한다. 근데 홍수 사상번호도 index 로 사용해야 되는게 아닌가? 하는 불안감이 있긴한다.  multiindex 라는 것이 있다고 한다. 나중에 필요하면 해당 키워드로 찾아 볼 것
#
# ## 아니다 date 로 하면 datetime 기준으로 하기 때문에 비어있는 데이터들에 대해서 자동적으로 채워준다. 이렇게 되면 안되기 때문에 index 로 사용하지 않기로 결정

# %%
# df = df.set_index('date')
# df.head()

# %%
feature_col = ['데이터집단 1', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','데이터집단 2','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','데이터집단 3','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','데이터 집단 4','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31','Unnamed: 32','Unnamed: 33','데이터 집단 5','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','데이터 집단 6','Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','avg_A_waterfall', 'avg_B_waterfall', 'avg_C_waterfall', 'avg_D_waterfall', 'avg_D_waterlevel', 'avg_E_waterlevel','avg_datagroup']
label_col = ['유입량']

# %%
def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
# 325 는 홍수 번호 23, 24, 25 를 의미. 일단은 여기에 있는 값을 예측하도록 만들어 보자.
# 홍수 번호 22 까지 train set 으로 설정하고, 23,24,25 는 test set 으로 설정!
TEST_SIZE = 325
train = df[:-TEST_SIZE]
test = df[-TEST_SIZE:]

train_feature = train[feature_col]
train_label = train[label_col]

# %% [markdown]
# # train_feature 는 일단 홍수 번호 22 까지만 포함하였다.

# %%
print(len(train_feature),len(train_label))
# Out:
# 2566 2566

# %%
train_feature
# Out:
#        데이터집단 1  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0     0.019488    0.021277    0.019074    0.027668     0.030534     0.093930
# 1     0.019184    0.021277    0.021798    0.027668     0.030534     0.093291
# 2     0.019488    0.021277    0.024523    0.027668     0.030534     0.093291
# 3     0.022229    0.021277    0.027248    0.027668     0.030534     0.093291
# 4     0.024970    0.021277    0.032698    0.031621     0.038168     0.093291
# ...        ...         ...         ...         ...          ...          ...
# 2561  0.097267    0.136778    0.114441    0.035573     0.026718     0.174441
# 2562  0.097140    0.136778    0.114441    0.035573     0.019084     0.173163
# 2563  0.097140    0.136778    0.114441    0.035573     0.019084     0.172524
# 2564  0.097140    0.136778    0.114441    0.035573     0.019084     0.171885
# 2565  0.097140    0.136778    0.114441    0.035573     0.019084     0.171246
#
#       Unnamed: 12   데이터집단 2  Unnamed: 14  Unnamed: 15  ...  Unnamed: 45  \
# 0        0.153560  0.019184     0.020772     0.019074  ...     0.030651
# 1        0.153312  0.019488     0.020772     0.021798  ...     0.038314
# 2        0.153064  0.022229     0.020772     0.024523  ...     0.042146
# 3        0.153064  0.024970     0.020772     0.027248  ...     0.053640
# 4        0.153064  0.034409     0.026706     0.032698  ...     0.061303
# ...           ...       ...          ...          ...  ...          ...
# 2561     0.654924  0.097140     0.133531     0.114441  ...     0.019157
# 2562     0.654924  0.097140     0.133531     0.114441  ...     0.019157
# 2563     0.654924  0.097140     0.133531     0.114441  ...     0.019157
# 2564     0.654924  0.097140     0.133531     0.114441  ...     0.019157
# 2565     0.654924  0.097140     0.133531     0.114441  ...     0.019157
#
#       Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0        0.093930     0.155313         0.020875         0.019462
# 1        0.093291     0.154916         0.020875         0.022243
# 2        0.093291     0.154518         0.020875         0.025023
# 3        0.093291     0.154320         0.023857         0.027804
# 4        0.093291     0.153923         0.030318         0.033364
# ...           ...          ...              ...              ...
# 2561     0.174441     0.655412         0.134195         0.116775
# 2562     0.173163     0.655412         0.134195         0.113994
# 2563     0.172524     0.655412         0.134195         0.113068
# 2564     0.171885     0.655412         0.134195         0.113068
# 2565     0.171246     0.655412         0.134195         0.111677
#
#       avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel  \
# 0            0.030201         0.030908          0.093930          0.155043
# 1            0.034228         0.034771          0.093291          0.154919
# 2            0.034899         0.036703          0.093291          0.154795
# 3            0.046980         0.043786          0.093291          0.154719
# 4            0.055034         0.050869          0.093291          0.154507
# ...               ...              ...               ...               ...
# 2561         0.048322         0.021893          0.174441          0.655578
# 2562         0.046980         0.019317          0.173163          0.655628
# 2563         0.043624         0.019317          0.172524          0.655678
# 2564         0.043624         0.019317          0.171885          0.655728
# 2565         0.041611         0.019317          0.171246          0.655752
#
#       avg_datagroup
# 0          0.019538
# 1          0.020972
# 2          0.023328
# 3          0.029474
# 4          0.037874
# ...             ...
# 2561       0.097944
# 2562       0.096968
# 2563       0.095525
# 2564       0.094381
# 2565       0.093298
#
# [2566 rows x 49 columns]

# %%
train_label
# Out:
#            유입량
# 0     0.008630
# 1     0.009926
# 2     0.011529
# 3     0.013919
# 4     0.017731
# ...        ...
# 2561  0.032520
# 2562  0.031548
# 2563  0.030498
# 2564  0.029575
# 2565  0.029013
#
# [2566 rows x 1 columns]

# %% [markdown]
# # 여기 윗까지 일단 train_label 이랑, train_feature 를 나누는 것에 성공을 하였다.

# %%
# train dataset
train_feature, train_label = make_dataset(train_feature, train_label, 20)

# %%
print(len(train_feature), len(train_label))
# Out:
# 2546 2546

# %%
train_label
# Out:
# array([[0.06010701],
#        [0.05826407],
#        [0.05869976],
#        ...,
#        [0.03049788],
#        [0.0295746 ],
#        [0.02901311]])

# %%
train_feature
# Out:
# array([[[0.01948843, 0.0212766 , 0.01907357, ..., 0.09392971,
#          0.15504297, 0.019538  ],
#         [0.01918392, 0.0212766 , 0.02179837, ..., 0.09329073,
#          0.15491893, 0.02097209],
#         [0.01948843, 0.0212766 , 0.02452316, ..., 0.09329073,
#          0.15479488, 0.02332811],
#         ...,
#         [0.17356882, 0.12462006, 0.16621253, ..., 0.18913738,
#          0.15296667, 0.17974722],
#         [0.1772229 , 0.12462006, 0.16893733, ..., 0.19744409,
#          0.15393783, 0.18276907],
#         [0.18087698, 0.13069909, 0.17166213, ..., 0.20127796,
#          0.15519928, 0.18492021]],
#
#        [[0.01918392, 0.0212766 , 0.02179837, ..., 0.09329073,
#          0.15491893, 0.02097209],
#         [0.01948843, 0.0212766 , 0.02452316, ..., 0.09329073,
#          0.15479488, 0.02332811],
#         [0.02222899, 0.0212766 , 0.02724796, ..., 0.09329073,
#          0.15471886, 0.02947425],
#         ...,
#         [0.1772229 , 0.12462006, 0.16893733, ..., 0.19744409,
#          0.15393783, 0.18276907],
#         [0.18087698, 0.13069909, 0.17166213, ..., 0.20127796,
#          0.15519928, 0.18492021],
#         [0.18392205, 0.1337386 , 0.17438692, ..., 0.20191693,
#          0.15661915, 0.18691771]],
#
#        [[0.01948843, 0.0212766 , 0.02452316, ..., 0.09329073,
#          0.15479488, 0.02332811],
#         [0.02222899, 0.0212766 , 0.02724796, ..., 0.09329073,
#          0.15471886, 0.02947425],
#         [0.02496955, 0.0212766 , 0.03269755, ..., 0.09329073,
#          0.1545072 , 0.03787396],
#         ...,
#         [0.18087698, 0.13069909, 0.17166213, ..., 0.20127796,
#          0.15519928, 0.18492021],
#         [0.18392205, 0.1337386 , 0.17438692, ..., 0.20191693,
#          0.15661915, 0.18691771],
#         [0.18574909, 0.13677812, 0.17711172, ..., 0.20255591,
#          0.15818578, 0.1886079 ]],
#
#        ...,
#
#        [[0.06727284, 0.12765957, 0.02179837, ..., 0.1942492 ,
#          0.65021627, 0.06822603],
#         [0.06746437, 0.12765957, 0.02179837, ..., 0.19233227,
#          0.65086127, 0.06866717],
#         [0.06788429, 0.12765957, 0.02179837, ..., 0.18977636,
#          0.65140966, 0.06996687],
#         ...,
#         [0.09726736, 0.13677812, 0.11444142, ..., 0.17571885,
#          0.65552765, 0.09807048],
#         [0.09726736, 0.13677812, 0.11444142, ..., 0.17444089,
#          0.6555778 , 0.09794356],
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.17316294,
#          0.65562796, 0.09696771]],
#
#        [[0.06746437, 0.12765957, 0.02179837, ..., 0.19233227,
#          0.65086127, 0.06866717],
#         [0.06788429, 0.12765957, 0.02179837, ..., 0.18977636,
#          0.65140966, 0.06996687],
#         [0.06845706, 0.12765957, 0.02724796, ..., 0.18913738,
#          0.65187635, 0.07194265],
#         ...,
#         [0.09726736, 0.13677812, 0.11444142, ..., 0.17444089,
#          0.6555778 , 0.09794356],
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.17316294,
#          0.65562796, 0.09696771],
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.17252396,
#          0.65567811, 0.09552511]],
#
#        [[0.06788429, 0.12765957, 0.02179837, ..., 0.18977636,
#          0.65140966, 0.06996687],
#         [0.06845706, 0.12765957, 0.02724796, ..., 0.18913738,
#          0.65187635, 0.07194265],
#         [0.07051096, 0.12765957, 0.02724796, ..., 0.18722045,
#          0.65234305, 0.07442369],
#         ...,
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.17316294,
#          0.65562796, 0.09696771],
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.17252396,
#          0.65567811, 0.09552511],
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.17188498,
#          0.65572827, 0.09438065]]])

# %% [markdown]
# # train dataset 과 validation dataset 의 분리
# test size 는 633 이라는 갯수는 23,24,25 홍수 번호를 사용하는 것이다

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=633)
print("x_train.shape", "x_valid.shape")
print(x_train.shape, x_valid.shape)
print("y_train, y_valid")
print(y_train.shape, y_valid.shape)
#(1981, 20, 48) (850, 20, 48)

test_feature = test[feature_col]
test_label = test[label_col]



# test dataset (실제 예측 해볼 데이터)
test_feature, test_label = make_dataset(test_feature, test_label, 20)
print("test_feature.shape, test_label.shape")
print(test_feature.shape, test_label.shape)
# ((180, 20, 4), (180, 1))
# Out:
# x_train.shape x_valid.shape
# (1913, 20, 49) (633, 20, 49)
# y_train, y_valid
# (1913, 1) (633, 1)
# test_feature.shape, test_label.shape
# (305, 20, 49) (305, 1)

# %% [markdown]
# # 아 train_featureshape[1] 이라는게 time step 을 의미하는 것인가?

# %%
print(train_feature.shape[0])
print(train_feature.shape[1])
# Out:
# 2546
# 20

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM
import tensorflow as tf
import os
model = Sequential()
model.add(LSTM(20,input_shape=(train_feature.shape[1], train_feature.shape[2]),activation='relu',return_sequences=False))
model.add(Dense(1))
model.compile(loss = 'mean_squared_error', optimizer='adam', metrics = ['accuracy'])

early_stop = EarlyStopping(monitor='val_loss', patience=5)
filename = os.path.join('tmp_checkpoint.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 20)                5600
# _________________________________________________________________
# dense (Dense)                (None, 1)                 21
# =================================================================
# Total params: 5,621
# Trainable params: 5,621
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2021-08-19 21:56:32.312544: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
from os.path import join
from tensorflow.keras.optimizers import RMSprop
# opt = RMSprop(lr=0.001)

model.compile(loss='mean_squared_error', optimizer = 'adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)
filename = os.path.join('tmp_checkpoint.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train, 
                    epochs=100, 
                    batch_size=16,
                    verbose = 1,
                    validation_data=(x_valid, y_valid),
                    callbacks=[early_stop, checkpoint])  
# history = model.fit(x_train, y_train, 
#                     epochs=100, 
#                     batch_size=16,
#                     verbose = 1,
#                     validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/100
# 2021-08-19 21:56:32.559470: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 120/120 [==============================] - 19s 10ms/step - loss: 0.0398 - val_loss: 0.0026
#
# Epoch 00001: val_loss improved from inf to 0.00258, saving model to tmp_checkpoint.h5
# Epoch 2/100
# 120/120 [==============================] - 1s 5ms/step - loss: 0.0031 - val_loss: 0.0012
#
# Epoch 00002: val_loss improved from 0.00258 to 0.00123, saving model to tmp_checkpoint.h5
# Epoch 3/100
# 120/120 [==============================] - 1s 4ms/step - loss: 0.0012 - val_loss: 7.9682e-04
#
# Epoch 00003: val_loss improved from 0.00123 to 0.00080, saving model to tmp_checkpoint.h5
# Epoch 4/100
# 120/120 [==============================] - 1s 5ms/step - loss: 6.1378e-04 - val_loss: 7.2494e-04
#
# Epoch 00004: val_loss improved from 0.00080 to 0.00072, saving model to tmp_checkpoint.h5
# Epoch 5/100
# 120/120 [==============================] - 1s 5ms/step - loss: 6.4470e-04 - val_loss: 7.7219e-04
#
# Epoch 00005: val_loss did not improve from 0.00072
# Epoch 6/100
# 120/120 [==============================] - 1s 5ms/step - loss: 7.6153e-04 - val_loss: 6.6501e-04
#
# Epoch 00006: val_loss improved from 0.00072 to 0.00067, saving model to tmp_checkpoint.h5
# Epoch 7/100
# 120/120 [==============================] - 1s 5ms/step - loss: 5.4389e-04 - val_loss: 6.3543e-04
#
# Epoch 00007: val_loss improved from 0.00067 to 0.00064, saving model to tmp_checkpoint.h5
# Epoch 8/100
# 120/120 [==============================] - 1s 5ms/step - loss: 5.0960e-04 - val_loss: 5.7282e-04
#
# Epoch 00008: val_loss improved from 0.00064 to 0.00057, saving model to tmp_checkpoint.h5
# Epoch 9/100
# 120/120 [==============================] - 1s 5ms/step - loss: 5.2689e-04 - val_loss: 6.1213e-04
#
# Epoch 00009: val_loss did not improve from 0.00057
# Epoch 10/100
# 120/120 [==============================] - 1s 5ms/step - loss: 6.1711e-04 - val_loss: 7.2268e-04
#
# Epoch 00010: val_loss did not improve from 0.00057
# Epoch 11/100
# 120/120 [==============================] - 1s 5ms/step - loss: 5.1326e-04 - val_loss: 5.2030e-04
#
# Epoch 00011: val_loss improved from 0.00057 to 0.00052, saving model to tmp_checkpoint.h5
# Epoch 12/100
# 120/120 [==============================] - 1s 5ms/step - loss: 4.8386e-04 - val_loss: 5.2936e-04
#
# Epoch 00012: val_loss did not improve from 0.00052
# Epoch 13/100
# 120/120 [==============================] - 1s 5ms/step - loss: 4.6264e-04 - val_loss: 5.4371e-04
#
# Epoch 00013: val_loss did not improve from 0.00052
# Epoch 14/100
# 120/120 [==============================] - 1s 5ms/step - loss: 6.2175e-04 - val_loss: 6.8181e-04
#
# Epoch 00014: val_loss did not improve from 0.00052
# Epoch 15/100
# 120/120 [==============================] - 1s 5ms/step - loss: 6.4051e-04 - val_loss: 4.8682e-04
#
# Epoch 00015: val_loss improved from 0.00052 to 0.00049, saving model to tmp_checkpoint.h5
# Epoch 16/100
# 120/120 [==============================] - 1s 5ms/step - loss: 4.9360e-04 - val_loss: 5.4199e-04
#
# Epoch 00016: val_loss did not improve from 0.00049
# Epoch 17/100
# 120/120 [==============================] - 1s 5ms/step - loss: 4.7157e-04 - val_loss: 5.3551e-04
#
# Epoch 00017: val_loss did not improve from 0.00049
# Epoch 18/100
# 120/120 [==============================] - 1s 5ms/step - loss: 4.4633e-04 - val_loss: 4.7573e-04
#
# Epoch 00018: val_loss improved from 0.00049 to 0.00048, saving model to tmp_checkpoint.h5
# Epoch 19/100
# 120/120 [==============================] - 1s 5ms/step - loss: 4.2288e-04 - val_loss: 5.0023e-04
#
# Epoch 00019: val_loss did not improve from 0.00048
# Epoch 20/100
# 120/120 [==============================] - 1s 5ms/step - loss: 4.4544e-04 - val_loss: 5.1894e-04
#
# Epoch 00020: val_loss did not improve from 0.00048
# Epoch 21/100
# 120/120 [==============================] - 1s 5ms/step - loss: 5.5215e-04 - val_loss: 4.6157e-04
#
# Epoch 00021: val_loss improved from 0.00048 to 0.00046, saving model to tmp_checkpoint.h5
# Epoch 22/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.7112e-04 - val_loss: 4.6961e-04
#
# Epoch 00022: val_loss did not improve from 0.00046
# Epoch 23/100
# 120/120 [==============================] - 1s 5ms/step - loss: 4.0500e-04 - val_loss: 5.4907e-04
#
# Epoch 00023: val_loss did not improve from 0.00046
# Epoch 24/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.5193e-04 - val_loss: 4.9290e-04
#
# Epoch 00024: val_loss did not improve from 0.00046
# Epoch 25/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.8032e-04 - val_loss: 4.3031e-04
#
# Epoch 00025: val_loss improved from 0.00046 to 0.00043, saving model to tmp_checkpoint.h5
# Epoch 26/100
# 120/120 [==============================] - 1s 5ms/step - loss: 7.4807e-04 - val_loss: 6.5766e-04
#
# Epoch 00026: val_loss did not improve from 0.00043
# Epoch 27/100
# 120/120 [==============================] - 1s 5ms/step - loss: 5.0238e-04 - val_loss: 4.2794e-04
#
# Epoch 00027: val_loss improved from 0.00043 to 0.00043, saving model to tmp_checkpoint.h5
# Epoch 28/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.5486e-04 - val_loss: 4.1798e-04
#
# Epoch 00028: val_loss improved from 0.00043 to 0.00042, saving model to tmp_checkpoint.h5
# Epoch 29/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.3551e-04 - val_loss: 4.8881e-04
#
# Epoch 00029: val_loss did not improve from 0.00042
# Epoch 30/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.7861e-04 - val_loss: 4.4009e-04
#
# Epoch 00030: val_loss did not improve from 0.00042
# Epoch 31/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.3884e-04 - val_loss: 4.1009e-04
#
# Epoch 00031: val_loss improved from 0.00042 to 0.00041, saving model to tmp_checkpoint.h5
# Epoch 32/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.7361e-04 - val_loss: 4.4018e-04
#
# Epoch 00032: val_loss did not improve from 0.00041
# Epoch 33/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.3422e-04 - val_loss: 4.8430e-04
#
# Epoch 00033: val_loss did not improve from 0.00041
# Epoch 34/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.4031e-04 - val_loss: 5.5951e-04
#
# Epoch 00034: val_loss did not improve from 0.00041
# Epoch 35/100
# 120/120 [==============================] - 1s 5ms/step - loss: 4.6073e-04 - val_loss: 4.6432e-04
#
# Epoch 00035: val_loss did not improve from 0.00041
# Epoch 36/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.6197e-04 - val_loss: 4.0431e-04
#
# Epoch 00036: val_loss improved from 0.00041 to 0.00040, saving model to tmp_checkpoint.h5
# Epoch 37/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.3197e-04 - val_loss: 3.8607e-04
#
# Epoch 00037: val_loss improved from 0.00040 to 0.00039, saving model to tmp_checkpoint.h5
# Epoch 38/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.2695e-04 - val_loss: 4.2336e-04
#
# Epoch 00038: val_loss did not improve from 0.00039
# Epoch 39/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.3354e-04 - val_loss: 3.6664e-04
#
# Epoch 00039: val_loss improved from 0.00039 to 0.00037, saving model to tmp_checkpoint.h5
# Epoch 40/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.2526e-04 - val_loss: 4.6197e-04
#
# Epoch 00040: val_loss did not improve from 0.00037
# Epoch 41/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.8982e-04 - val_loss: 3.8825e-04
#
# Epoch 00041: val_loss did not improve from 0.00037
# Epoch 42/100
# 120/120 [==============================] - 1s 5ms/step - loss: 2.8294e-04 - val_loss: 7.2967e-04
#
# Epoch 00042: val_loss did not improve from 0.00037
# Epoch 43/100
# 120/120 [==============================] - 1s 5ms/step - loss: 4.4727e-04 - val_loss: 3.9028e-04
#
# Epoch 00043: val_loss did not improve from 0.00037
# Epoch 44/100
# 120/120 [==============================] - 1s 5ms/step - loss: 3.8762e-04 - val_loss: 4.0559e-04
#
# Epoch 00044: val_loss did not improve from 0.00037

# %%
model.load_weights(filename)
pred = model.predict(test_feature)

# %% [markdown]
# # RMSE 뽑아 내기

# %%
from sklearn.metrics import mean_squared_error
RMSE = mean_squared_error(test_label,pred)**0.5
RMSE
# Out:
# 0.03278125853487953

# %%
plt.figure(figsize=(12, 9))
plt.plot(test_label, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()
