# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os.path import join
from sklearn.model_selection import train_test_split

# %% [markdown]
# # feature engineering
#
# 열병합 한 상태로 진행

# %%
from os.path import join
df = pd.read_excel('rain_data.xlsx')
df.head()
# Out:
#    홍수사상번호     연  월   일  시간         유입량  데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1  2006  7  10   8  189.100000      6.4           7           7
# 1       1  2006  7  10   9  216.951962      6.3           7           8
# 2       1  2006  7  10  10  251.424419      6.4           7           9
# 3       1  2006  7  10  11  302.812199      7.3           7          10
# 4       1  2006  7  10  12  384.783406      8.2           7          12
#
#    Unnamed: 9  ...  Unnamed: 38  Unnamed: 39  Unnamed: 40  데이터 집단 6  \
# 0           7  ...            8         2.54      122.660       6.4
# 1           7  ...           10         2.53      122.648       7.3
# 2           7  ...           11         2.53      122.636       8.2
# 3           7  ...           14         2.53      122.620      11.3
# 4           8  ...           16         2.53      122.604      14.4
#
#    Unnamed: 42  Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  \
# 0            7            7            8            8         2.54
# 1            7            8           10           10         2.53
# 2            7            9           10           11         2.53
# 3            9           10           15           14         2.53
# 4           12           12           18           16         2.53
#
#    Unnamed: 47
# 0      122.610
# 1      122.600
# 2      122.590
# 3      122.585
# 4      122.575
#
# [5 rows x 48 columns]

# %% [markdown]
# # 연,월,일,시간 을 datetime format 으로 변경
#
# ## 시간 의 경우, datetime 에서 24 를 인식하지 못한다. 비슷한 맥락이므로 -1 을 진행하여 붙힌다

# %%
df['시간'] = df['시간']-1
df.head()
# Out:
#    홍수사상번호     연  월   일  시간         유입량  데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1  2006  7  10   7  189.100000      6.4           7           7
# 1       1  2006  7  10   8  216.951962      6.3           7           8
# 2       1  2006  7  10   9  251.424419      6.4           7           9
# 3       1  2006  7  10  10  302.812199      7.3           7          10
# 4       1  2006  7  10  11  384.783406      8.2           7          12
#
#    Unnamed: 9  ...  Unnamed: 38  Unnamed: 39  Unnamed: 40  데이터 집단 6  \
# 0           7  ...            8         2.54      122.660       6.4
# 1           7  ...           10         2.53      122.648       7.3
# 2           7  ...           11         2.53      122.636       8.2
# 3           7  ...           14         2.53      122.620      11.3
# 4           8  ...           16         2.53      122.604      14.4
#
#    Unnamed: 42  Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  \
# 0            7            7            8            8         2.54
# 1            7            8           10           10         2.53
# 2            7            9           10           11         2.53
# 3            9           10           15           14         2.53
# 4           12           12           18           16         2.53
#
#    Unnamed: 47
# 0      122.610
# 1      122.600
# 2      122.590
# 3      122.585
# 4      122.575
#
# [5 rows x 48 columns]

# %% [markdown]
# ## 연 월 일 시간 을 datetime 으로 한번에 붙힌다.

# %% [markdown]
# ### dateInt 잘 들어갔는지 확인

# %%
df['dateInt']= df['연'].astype(str) + df['월'].astype(str).str.zfill(2)+df['일'].astype(str).str.zfill(2)+df['시간'].astype(str).str.zfill(2)
df['dateInt']
# Out:
# 0       2006071007
# 1       2006071008
# 2       2006071009
# 3       2006071010
# 4       2006071011
#            ...
# 3046    2018070716
# 3047    2018070717
# 3048    2018070718
# 3049    2018070719
# 3050    2018070720
# Name: dateInt, Length: 3051, dtype: object

# %% [markdown]
# ### dateInt 를 datetime format 으로 변경하여 Date 라는 칼럼에 저장

# %%
df['Date'] = pd.to_datetime(df['dateInt'], format="%Y%m%d%H")
df['Date']
# Out:
# 0      2006-07-10 07:00:00
# 1      2006-07-10 08:00:00
# 2      2006-07-10 09:00:00
# 3      2006-07-10 10:00:00
# 4      2006-07-10 11:00:00
#                ...
# 3046   2018-07-07 16:00:00
# 3047   2018-07-07 17:00:00
# 3048   2018-07-07 18:00:00
# 3049   2018-07-07 19:00:00
# 3050   2018-07-07 20:00:00
# Name: Date, Length: 3051, dtype: datetime64[ns]

# %% [markdown]
# ### Date 칼럼이 제일 뒤로 갔으므로 앞으로 당겨서 사용할 것임. insert 사용

# %%
df.insert(4, 'date', value = df['Date'])
df.head()
# Out:
#    홍수사상번호     연  월   일                date  시간         유입량  데이터집단 1  \
# 0       1  2006  7  10 2006-07-10 07:00:00   7  189.100000      6.4
# 1       1  2006  7  10 2006-07-10 08:00:00   8  216.951962      6.3
# 2       1  2006  7  10 2006-07-10 09:00:00   9  251.424419      6.4
# 3       1  2006  7  10 2006-07-10 10:00:00  10  302.812199      7.3
# 4       1  2006  7  10 2006-07-10 11:00:00  11  384.783406      8.2
#
#    Unnamed: 7  Unnamed: 8  ...  Unnamed: 40  데이터 집단 6  Unnamed: 42  \
# 0           7           7  ...      122.660       6.4            7
# 1           7           8  ...      122.648       7.3            7
# 2           7           9  ...      122.636       8.2            7
# 3           7          10  ...      122.620      11.3            9
# 4           7          12  ...      122.604      14.4           12
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0            7            8            8         2.54      122.610
# 1            8           10           10         2.53      122.600
# 2            9           10           11         2.53      122.590
# 3           10           15           14         2.53      122.585
# 4           12           18           16         2.53      122.575
#
#       dateInt                Date
# 0  2006071007 2006-07-10 07:00:00
# 1  2006071008 2006-07-10 08:00:00
# 2  2006071009 2006-07-10 09:00:00
# 3  2006071010 2006-07-10 10:00:00
# 4  2006071011 2006-07-10 11:00:00
#
# [5 rows x 51 columns]

# %% [markdown]
# ### date 라는 칼럼 하나만 사용할 예정이기에, 연,월,일,시간,dateInt, Date 를 drop

# %%
df =df.drop(['연','월','일','시간','dateInt','Date'], axis = 1)
df.head()
# Out:
#    홍수사상번호                date         유입량  데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1 2006-07-10 07:00:00  189.100000      6.4           7           7
# 1       1 2006-07-10 08:00:00  216.951962      6.3           7           8
# 2       1 2006-07-10 09:00:00  251.424419      6.4           7           9
# 3       1 2006-07-10 10:00:00  302.812199      7.3           7          10
# 4       1 2006-07-10 11:00:00  384.783406      8.2           7          12
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 38  \
# 0           7            8         2.54    122.56875  ...            8
# 1           7            8         2.53    122.56250  ...           10
# 2           7            8         2.53    122.55625  ...           11
# 3           7            8         2.53    122.55625  ...           14
# 4           8           10         2.53    122.55625  ...           16
#
#    Unnamed: 39  Unnamed: 40  데이터 집단 6  Unnamed: 42  Unnamed: 43  Unnamed: 44  \
# 0         2.54      122.660       6.4            7            7            8
# 1         2.53      122.648       7.3            7            8           10
# 2         2.53      122.636       8.2            7            9           10
# 3         2.53      122.620      11.3            9           10           15
# 4         2.53      122.604      14.4           12           12           18
#
#    Unnamed: 45  Unnamed: 46  Unnamed: 47
# 0            8         2.54      122.610
# 1           10         2.53      122.600
# 2           11         2.53      122.590
# 3           14         2.53      122.585
# 4           16         2.53      122.575
#
# [5 rows x 45 columns]

# %% [markdown]
# # date, 홍수 사상번호 두개 다 index 로 사용해야될 것 같다고 생각. 나중에 시도해 볼것

# %% [markdown]
# ### date 를 index 로 사용
# #### 해 봤는데, date 로 진행하게 되면 얘가 그래프를 그릴때도, 비어있는 데이터에 대해서 (1,2,3,4,5, 9,10,11,12 월 ) 는 값이 없어서 아예 평균을 내는 현상을 발견함.
# - index 는 date 로 하면 안되는 거 같음.
# - 아... date 데이터 한번 사용해보고 싶었는데... 좀만 더 생각을 해보자.

# %%
# df = df.set_index('date')
# df.head()

# %% [markdown]
# # 데이터 집단 1-6 안에 있는 a-e 데이터를 아예 평균을 내서 새로운 feature 로 저장

# %%
df['avg_A_waterfall']  = (df['Unnamed: 7']  + df['Unnamed: 14'] +df['Unnamed: 21'] +df['Unnamed: 28'] +df['Unnamed: 35'] +df['Unnamed: 42'])/6
df['avg_B_waterfall']  = (df['Unnamed: 8']  + df['Unnamed: 15'] +df['Unnamed: 22'] +df['Unnamed: 29'] +df['Unnamed: 36'] +df['Unnamed: 43'])/6
df['avg_C_waterfall']  = (df['Unnamed: 9']  + df['Unnamed: 16'] +df['Unnamed: 23'] +df['Unnamed: 30'] +df['Unnamed: 37'] +df['Unnamed: 44'])/6
df['avg_D_waterfall']  = (df['Unnamed: 10'] + df['Unnamed: 17'] +df['Unnamed: 24'] +df['Unnamed: 31'] +df['Unnamed: 38'] +df['Unnamed: 45'])/6
df['avg_D_waterlevel'] = (df['Unnamed: 11'] + df['Unnamed: 18'] +df['Unnamed: 25'] +df['Unnamed: 32'] +df['Unnamed: 39'] +df['Unnamed: 46'])/6
df['avg_E_waterlevel'] = (df['Unnamed: 12'] + df['Unnamed: 19'] +df['Unnamed: 26'] +df['Unnamed: 33'] +df['Unnamed: 40'] +df['Unnamed: 47'])/6
df.head()
# Out:
#    홍수사상번호                date       유입량   데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1 2006-07-10 07:00:00  0.008630  0.019488    0.021277    0.019074
# 1       1 2006-07-10 08:00:00  0.009926  0.019184    0.021277    0.021798
# 2       1 2006-07-10 09:00:00  0.011529  0.019488    0.021277    0.024523
# 3       1 2006-07-10 10:00:00  0.013919  0.022229    0.021277    0.027248
# 4       1 2006-07-10 11:00:00  0.017731  0.024970    0.021277    0.032698
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 44  \
# 0    0.027668     0.030534     0.093930     0.153560  ...     0.032389
# 1    0.027668     0.030534     0.093291     0.153312  ...     0.040486
# 2    0.027668     0.030534     0.093291     0.153064  ...     0.040486
# 3    0.027668     0.030534     0.093291     0.153064  ...     0.060729
# 4    0.031621     0.038168     0.093291     0.153064  ...     0.072874
#
#    Unnamed: 45  Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0     0.030651     0.093930     0.155313         0.020615         0.019412
# 1     0.038314     0.093291     0.154916         0.020615         0.022185
# 2     0.042146     0.093291     0.154518         0.020615         0.024958
# 3     0.053640     0.093291     0.154320         0.023513         0.027731
# 4     0.061303     0.093291     0.153923         0.029839         0.033277
#
#    avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel
# 0         0.028967         0.030554          0.093930          0.154805
# 1         0.032732         0.034376          0.093291          0.154680
# 2         0.033396         0.036286          0.093291          0.154556
# 3         0.044801         0.043291          0.093291          0.154479
# 4         0.052435         0.050293          0.093291          0.154267
#
# [5 rows x 51 columns]

# %% [markdown]
# # scaling 진행 할 것-----> feature engineering 좀만 더 하다가 사용해보자.

# %%
feature_list = ['유입량','데이터집단 1', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','데이터집단 2','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','데이터집단 3','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','데이터 집단 4','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31','Unnamed: 32','Unnamed: 33','데이터 집단 5','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','데이터 집단 6','Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','avg_A_waterfall', 'avg_B_waterfall', 'avg_C_waterfall', 'avg_D_waterfall', 'avg_D_waterlevel', 'avg_E_waterlevel']

# %%
for sth in feature_list:
    norm_inflow = (df[sth]-df[sth].min())/(df[sth].max()-df[sth].min())
    df[sth]=norm_inflow
df.head()
# Out:
#    홍수사상번호                date       유입량   데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1 2006-07-10 07:00:00  0.008630  0.019488    0.021277    0.019074
# 1       1 2006-07-10 08:00:00  0.009926  0.019184    0.021277    0.021798
# 2       1 2006-07-10 09:00:00  0.011529  0.019488    0.021277    0.024523
# 3       1 2006-07-10 10:00:00  0.013919  0.022229    0.021277    0.027248
# 4       1 2006-07-10 11:00:00  0.017731  0.024970    0.021277    0.032698
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 44  \
# 0    0.027668     0.030534     0.093930     0.153560  ...     0.032389
# 1    0.027668     0.030534     0.093291     0.153312  ...     0.040486
# 2    0.027668     0.030534     0.093291     0.153064  ...     0.040486
# 3    0.027668     0.030534     0.093291     0.153064  ...     0.060729
# 4    0.031621     0.038168     0.093291     0.153064  ...     0.072874
#
#    Unnamed: 45  Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0     0.030651     0.093930     0.155313         0.020888         0.019466
# 1     0.038314     0.093291     0.154916         0.020888         0.022247
# 2     0.042146     0.093291     0.154518         0.020888         0.025028
# 3     0.053640     0.093291     0.154320         0.023826         0.027808
# 4     0.061303     0.093291     0.153923         0.030236         0.033370
#
#    avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel
# 0         0.030170         0.030908          0.093930          0.155047
# 1         0.034092         0.034774          0.093291          0.154922
# 2         0.034783         0.036707          0.093291          0.154798
# 3         0.046661         0.043794          0.093291          0.154721
# 4         0.054612         0.050877          0.093291          0.154509
#
# [5 rows x 51 columns]

# %%
plt.figure(figsize = (20,10))
plt.plot(df['유입량'])

# %% [markdown]
# # 만들어 놓은 데이터를 새로운 엑셀 파일로 저장

# %%
df.to_excel(excel_writer='0819_datetime_rain_data.xlsx')
df.head()
# Out:
#    홍수사상번호                date       유입량   데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1 2006-07-10 07:00:00  0.008630  0.019488    0.021277    0.019074
# 1       1 2006-07-10 08:00:00  0.009926  0.019184    0.021277    0.021798
# 2       1 2006-07-10 09:00:00  0.011529  0.019488    0.021277    0.024523
# 3       1 2006-07-10 10:00:00  0.013919  0.022229    0.021277    0.027248
# 4       1 2006-07-10 11:00:00  0.017731  0.024970    0.021277    0.032698
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 44  \
# 0    0.027668     0.030534     0.093930     0.153560  ...     0.032389
# 1    0.027668     0.030534     0.093291     0.153312  ...     0.040486
# 2    0.027668     0.030534     0.093291     0.153064  ...     0.040486
# 3    0.027668     0.030534     0.093291     0.153064  ...     0.060729
# 4    0.031621     0.038168     0.093291     0.153064  ...     0.072874
#
#    Unnamed: 45  Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0     0.030651     0.093930     0.155313         0.020888         0.019466
# 1     0.038314     0.093291     0.154916         0.020888         0.022247
# 2     0.042146     0.093291     0.154518         0.020888         0.025028
# 3     0.053640     0.093291     0.154320         0.023826         0.027808
# 4     0.061303     0.093291     0.153923         0.030236         0.033370
#
#    avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel
# 0         0.030170         0.030908          0.093930          0.155047
# 1         0.034092         0.034774          0.093291          0.154922
# 2         0.034783         0.036707          0.093291          0.154798
# 3         0.046661         0.043794          0.093291          0.154721
# 4         0.054612         0.050877          0.093291          0.154509
#
# [5 rows x 51 columns]

# %% [markdown]
# # index 설정을 안해서 그런가... 이상하게 값이 저장된다... 맨 앞에 있는 0123456789 가 계속해서 생성된다 저장을 할때마다.
#
# 일단은 저장을 할때 첫 row 는 삭제 하는 식으로 진행하자.

# %% [markdown]
# # excel 파일 분할 한 것 표시 일단은 하고, (테스트 용이니) 기존에 사용하던 데이터로 계속 진행.
#
# ## 엑셀파일을 귀찮아서 일단은 임의로 train, test 로 나눴다.
# ### train dataset 에는 1~25 까지의 데이터가 존재 하고
# ### test dataset 에는 26 만 데이터가 존재 하는 상황이다.

# %% [markdown]
# # 현재 데이터의 총 갯수는 2890 이다. feature 는 51 개

# %%
df = pd.read_excel('train(1-25)_scaled_avg.xlsx')
print(df.shape)
df.head()
# Out:
# (2891, 51)
#    홍수사상번호                date       유입량   데이터집단 1  Unnamed: 7  Unnamed: 8  \
# 0       1   2006-7-10 7:00:00  0.008630  0.019488    0.021277    0.019074
# 1       1   2006-7-10 8:00:00  0.009926  0.019184    0.021277    0.021798
# 2       1   2006-7-10 9:00:00  0.011529  0.019488    0.021277    0.024523
# 3       1  2006-7-10 10:00:00  0.013919  0.022229    0.021277    0.027248
# 4       1  2006-7-10 11:00:00  0.017731  0.024970    0.021277    0.032698
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  ...  Unnamed: 44  \
# 0    0.027668     0.030534     0.093930     0.153560  ...     0.032389
# 1    0.027668     0.030534     0.093291     0.153312  ...     0.040486
# 2    0.027668     0.030534     0.093291     0.153064  ...     0.040486
# 3    0.027668     0.030534     0.093291     0.153064  ...     0.060729
# 4    0.031621     0.038168     0.093291     0.153064  ...     0.072874
#
#    Unnamed: 45  Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0     0.030651     0.093930     0.155313         0.020875         0.019462
# 1     0.038314     0.093291     0.154916         0.020875         0.022243
# 2     0.042146     0.093291     0.154518         0.020875         0.025023
# 3     0.053640     0.093291     0.154320         0.023857         0.027804
# 4     0.061303     0.093291     0.153923         0.030318         0.033364
#
#    avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel
# 0         0.030201         0.030908          0.093930          0.155043
# 1         0.034228         0.034771          0.093291          0.154919
# 2         0.034899         0.036703          0.093291          0.154795
# 3         0.046980         0.043786          0.093291          0.154719
# 4         0.055034         0.050869          0.093291          0.154507
#
# [5 rows x 51 columns]

# %% [markdown]
# # date 를 index 로 사용하고자 한다. 근데 홍수 사상번호도 index 로 사용해야 되는게 아닌가? 하는 불안감이 있긴한다.  multiindex 라는 것이 있다고 한다. 나중에 필요하면 해당 키워드로 찾아 볼 것

# %%
# df = df.set_index('date')
# df.head()

# %%
feature_col = ['데이터집단 1', 'Unnamed: 7','Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','데이터집단 2','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','데이터집단 3','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25','Unnamed: 26','데이터 집단 4','Unnamed: 28','Unnamed: 29','Unnamed: 30','Unnamed: 31','Unnamed: 32','Unnamed: 33','데이터 집단 5','Unnamed: 35','Unnamed: 36','Unnamed: 37','Unnamed: 38','Unnamed: 39','Unnamed: 40','데이터 집단 6','Unnamed: 42','Unnamed: 43','Unnamed: 44','Unnamed: 45','Unnamed: 46','Unnamed: 47','avg_A_waterfall', 'avg_B_waterfall', 'avg_C_waterfall', 'avg_D_waterfall', 'avg_D_waterlevel', 'avg_E_waterlevel']
label_col = ['유입량']

# %%
def make_dataset(data, label, window_size=20):
    feature_list = []
    label_list = []
    for i in range(len(data) - window_size):
        feature_list.append(np.array(data.iloc[i:i+window_size]))
        label_list.append(np.array(label.iloc[i+window_size]))
    return np.array(feature_list), np.array(label_list)

# %%
# 325 는 홍수 번호 23, 24, 25 를 의미. 일단은 여기에 있는 값을 예측하도록 만들어 보자.
# 홍수 번호 22 까지 train set 으로 설정하고, 23,24,25 는 test set 으로 설정!
TEST_SIZE = 325
train = df[:-TEST_SIZE]
test = df[-TEST_SIZE:]

train_feature = train[feature_col]
train_label = train[label_col]

# %% [markdown]
# # train_feature 는 일단 홍수 번호 22 까지만 포함하였다.

# %%
print(len(train_feature),len(train_label))
# Out:
# 2566 2566

# %%
train_feature
# Out:
#        데이터집단 1  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11  \
# 0     0.019488    0.021277    0.019074    0.027668     0.030534     0.093930
# 1     0.019184    0.021277    0.021798    0.027668     0.030534     0.093291
# 2     0.019488    0.021277    0.024523    0.027668     0.030534     0.093291
# 3     0.022229    0.021277    0.027248    0.027668     0.030534     0.093291
# 4     0.024970    0.021277    0.032698    0.031621     0.038168     0.093291
# ...        ...         ...         ...         ...          ...          ...
# 2561  0.097267    0.136778    0.114441    0.035573     0.026718     0.174441
# 2562  0.097140    0.136778    0.114441    0.035573     0.019084     0.173163
# 2563  0.097140    0.136778    0.114441    0.035573     0.019084     0.172524
# 2564  0.097140    0.136778    0.114441    0.035573     0.019084     0.171885
# 2565  0.097140    0.136778    0.114441    0.035573     0.019084     0.171246
#
#       Unnamed: 12   데이터집단 2  Unnamed: 14  Unnamed: 15  ...  Unnamed: 44  \
# 0        0.153560  0.019184     0.020772     0.019074  ...     0.032389
# 1        0.153312  0.019488     0.020772     0.021798  ...     0.040486
# 2        0.153064  0.022229     0.020772     0.024523  ...     0.040486
# 3        0.153064  0.024970     0.020772     0.027248  ...     0.060729
# 4        0.153064  0.034409     0.026706     0.032698  ...     0.072874
# ...           ...       ...          ...          ...  ...          ...
# 2561     0.654924  0.097140     0.133531     0.114441  ...     0.036437
# 2562     0.654924  0.097140     0.133531     0.114441  ...     0.028340
# 2563     0.654924  0.097140     0.133531     0.114441  ...     0.008097
# 2564     0.654924  0.097140     0.133531     0.114441  ...     0.008097
# 2565     0.654924  0.097140     0.133531     0.114441  ...     0.004049
#
#       Unnamed: 45  Unnamed: 46  Unnamed: 47  avg_A_waterfall  avg_B_waterfall  \
# 0        0.030651     0.093930     0.155313         0.020875         0.019462
# 1        0.038314     0.093291     0.154916         0.020875         0.022243
# 2        0.042146     0.093291     0.154518         0.020875         0.025023
# 3        0.053640     0.093291     0.154320         0.023857         0.027804
# 4        0.061303     0.093291     0.153923         0.030318         0.033364
# ...           ...          ...          ...              ...              ...
# 2561     0.019157     0.174441     0.655412         0.134195         0.116775
# 2562     0.019157     0.173163     0.655412         0.134195         0.113994
# 2563     0.019157     0.172524     0.655412         0.134195         0.113068
# 2564     0.019157     0.171885     0.655412         0.134195         0.113068
# 2565     0.019157     0.171246     0.655412         0.134195         0.111677
#
#       avg_C_waterfall  avg_D_waterfall  avg_D_waterlevel  avg_E_waterlevel
# 0            0.030201         0.030908          0.093930          0.155043
# 1            0.034228         0.034771          0.093291          0.154919
# 2            0.034899         0.036703          0.093291          0.154795
# 3            0.046980         0.043786          0.093291          0.154719
# 4            0.055034         0.050869          0.093291          0.154507
# ...               ...              ...               ...               ...
# 2561         0.048322         0.021893          0.174441          0.655578
# 2562         0.046980         0.019317          0.173163          0.655628
# 2563         0.043624         0.019317          0.172524          0.655678
# 2564         0.043624         0.019317          0.171885          0.655728
# 2565         0.041611         0.019317          0.171246          0.655752
#
# [2566 rows x 48 columns]

# %%
train_label
# Out:
#            유입량
# 0     0.008630
# 1     0.009926
# 2     0.011529
# 3     0.013919
# 4     0.017731
# ...        ...
# 2561  0.032520
# 2562  0.031548
# 2563  0.030498
# 2564  0.029575
# 2565  0.029013
#
# [2566 rows x 1 columns]

# %% [markdown]
# # 여기 윗까지 일단 train_label 이랑, train_feature 를 나누는 것에 성공을 하였다.

# %%
# train dataset
train_feature, train_label = make_dataset(train_feature, train_label, 20)

# %%
print(len(train_feature), len(train_label))
# Out:
# 2546 2546

# %%
train_label
# Out:
# array([[0.06010701],
#        [0.05826407],
#        [0.05869976],
#        ...,
#        [0.03049788],
#        [0.0295746 ],
#        [0.02901311]])

# %%
train_feature
# Out:
# array([[[0.01948843, 0.0212766 , 0.01907357, ..., 0.03090792,
#          0.09392971, 0.15504297],
#         [0.01918392, 0.0212766 , 0.02179837, ..., 0.03477141,
#          0.09329073, 0.15491893],
#         [0.01948843, 0.0212766 , 0.02452316, ..., 0.03670316,
#          0.09329073, 0.15479488],
#         ...,
#         [0.17356882, 0.12462006, 0.16621253, ..., 0.23245332,
#          0.18913738, 0.15296667],
#         [0.1772229 , 0.12462006, 0.16893733, ..., 0.23438506,
#          0.19744409, 0.15393783],
#         [0.18087698, 0.13069909, 0.17166213, ..., 0.23889247,
#          0.20127796, 0.15519928]],
#
#        [[0.01918392, 0.0212766 , 0.02179837, ..., 0.03477141,
#          0.09329073, 0.15491893],
#         [0.01948843, 0.0212766 , 0.02452316, ..., 0.03670316,
#          0.09329073, 0.15479488],
#         [0.02222899, 0.0212766 , 0.02724796, ..., 0.04378622,
#          0.09329073, 0.15471886],
#         ...,
#         [0.1772229 , 0.12462006, 0.16893733, ..., 0.23438506,
#          0.19744409, 0.15393783],
#         [0.18087698, 0.13069909, 0.17166213, ..., 0.23889247,
#          0.20127796, 0.15519928],
#         [0.18392205, 0.1337386 , 0.17438692, ..., 0.24146813,
#          0.20191693, 0.15661915]],
#
#        [[0.01948843, 0.0212766 , 0.02452316, ..., 0.03670316,
#          0.09329073, 0.15479488],
#         [0.02222899, 0.0212766 , 0.02724796, ..., 0.04378622,
#          0.09329073, 0.15471886],
#         [0.02496955, 0.0212766 , 0.03269755, ..., 0.05086929,
#          0.09329073, 0.1545072 ],
#         ...,
#         [0.18087698, 0.13069909, 0.17166213, ..., 0.23889247,
#          0.20127796, 0.15519928],
#         [0.18392205, 0.1337386 , 0.17438692, ..., 0.24146813,
#          0.20191693, 0.15661915],
#         [0.18574909, 0.13677812, 0.17711172, ..., 0.24211204,
#          0.20255591, 0.15818578]],
#
#        ...,
#
#        [[0.06727284, 0.12765957, 0.02179837, ..., 0.03477141,
#          0.1942492 , 0.65021627],
#         [0.06746437, 0.12765957, 0.02179837, ..., 0.03670316,
#          0.19233227, 0.65086127],
#         [0.06788429, 0.12765957, 0.02179837, ..., 0.03670316,
#          0.18977636, 0.65140966],
#         ...,
#         [0.09726736, 0.13677812, 0.11444142, ..., 0.02446877,
#          0.17571885, 0.65552765],
#         [0.09726736, 0.13677812, 0.11444142, ..., 0.02189311,
#          0.17444089, 0.6555778 ],
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.01931745,
#          0.17316294, 0.65562796]],
#
#        [[0.06746437, 0.12765957, 0.02179837, ..., 0.03670316,
#          0.19233227, 0.65086127],
#         [0.06788429, 0.12765957, 0.02179837, ..., 0.03670316,
#          0.18977636, 0.65140966],
#         [0.06845706, 0.12765957, 0.02724796, ..., 0.03734707,
#          0.18913738, 0.65187635],
#         ...,
#         [0.09726736, 0.13677812, 0.11444142, ..., 0.02189311,
#          0.17444089, 0.6555778 ],
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.01931745,
#          0.17316294, 0.65562796],
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.01931745,
#          0.17252396, 0.65567811]],
#
#        [[0.06788429, 0.12765957, 0.02179837, ..., 0.03670316,
#          0.18977636, 0.65140966],
#         [0.06845706, 0.12765957, 0.02724796, ..., 0.03734707,
#          0.18913738, 0.65187635],
#         [0.07051096, 0.12765957, 0.02724796, ..., 0.0386349 ,
#          0.18722045, 0.65234305],
#         ...,
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.01931745,
#          0.17316294, 0.65562796],
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.01931745,
#          0.17252396, 0.65567811],
#         [0.09714038, 0.13677812, 0.11444142, ..., 0.01931745,
#          0.17188498, 0.65572827]]])

# %%
x_train, x_valid, y_train, y_valid = train_test_split(train_feature, train_label, test_size=633)
print("x_train.shape", "x_valid.shape")
print(x_train.shape, x_valid.shape)
print("y_train, y_valid")
print(y_train.shape, y_valid.shape)
#(1981, 20, 48) (850, 20, 48)

test_feature = test[feature_col]
test_label = test[label_col]



# test dataset (실제 예측 해볼 데이터)
test_feature, test_label = make_dataset(test_feature, test_label, 20)
print("test_feature.shape, test_label.shape")
print(test_feature.shape, test_label.shape)
# ((180, 20, 4), (180, 1))
# Out:
# x_train.shape x_valid.shape
# (1913, 20, 48) (633, 20, 48)
# y_train, y_valid
# (1913, 1) (633, 1)
# test_feature.shape, test_label.shape
# (305, 20, 48) (305, 1)

# %% [markdown]
# # 아 train_featureshape[1] 이라는게 time step 을 의미하는 것인가?

# %%
print(train_feature.shape[0])
print(train_feature.shape[1])
# Out:
# 2546
# 20

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers import LSTM
import tensorflow as tf


model = Sequential()
model.add(LSTM(100,input_shape=(train_feature.shape[1], train_feature.shape[2]),activation='relu',return_sequences=False))
model.add(Dense(1))
model.compile(loss = 'mean_squared_error', optimizer='RMSprop', metrics = ['accuracy'])

# early_stop = EarlyStopping(monitor='val_loss', patience=5)
# filename = os.path.join('tmp_checkpoint.h5')
# checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               59600
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 59,701
# Trainable params: 59,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2021-08-19 16:49:11.925090: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import os
from os.path import join
from tensorflow.keras.optimizers import RMSprop
# opt = RMSprop(lr=0.001)

model.compile(loss='mean_squared_error', optimizer = 'adam')
early_stop = EarlyStopping(monitor='val_loss', patience=5)
filename = os.path.join('tmp_checkpoint.h5')
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='auto')

history = model.fit(x_train, y_train, 
                    epochs=200, 
                    batch_size=16,
                    verbose = 2,
                    validation_data=(x_valid, y_valid),
                    callbacks=[early_stop, checkpoint])
# Out:
# 2021-08-19 16:49:12.393512: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 120/120 - 18s - loss: 0.0054 - val_loss: 0.0014
#
# Epoch 00001: val_loss improved from inf to 0.00138, saving model to tmp_checkpoint.h5
# Epoch 2/200
# 120/120 - 1s - loss: 0.0013 - val_loss: 0.0013
#
# Epoch 00002: val_loss improved from 0.00138 to 0.00127, saving model to tmp_checkpoint.h5
# Epoch 3/200
# 120/120 - 1s - loss: 8.0150e-04 - val_loss: 0.0011
#
# Epoch 00003: val_loss improved from 0.00127 to 0.00107, saving model to tmp_checkpoint.h5
# Epoch 4/200
# 120/120 - 1s - loss: 7.4614e-04 - val_loss: 7.5640e-04
#
# Epoch 00004: val_loss improved from 0.00107 to 0.00076, saving model to tmp_checkpoint.h5
# Epoch 5/200
# 120/120 - 1s - loss: 5.2597e-04 - val_loss: 7.3984e-04
#
# Epoch 00005: val_loss improved from 0.00076 to 0.00074, saving model to tmp_checkpoint.h5
# Epoch 6/200
# 120/120 - 1s - loss: 5.2038e-04 - val_loss: 6.3753e-04
#
# Epoch 00006: val_loss improved from 0.00074 to 0.00064, saving model to tmp_checkpoint.h5
# Epoch 7/200
# 120/120 - 1s - loss: 4.0301e-04 - val_loss: 6.7701e-04
#
# Epoch 00007: val_loss did not improve from 0.00064
# Epoch 8/200
# 120/120 - 1s - loss: 4.0963e-04 - val_loss: 4.3960e-04
#
# Epoch 00008: val_loss improved from 0.00064 to 0.00044, saving model to tmp_checkpoint.h5
# Epoch 9/200
# 120/120 - 1s - loss: 5.3553e-04 - val_loss: 4.3581e-04
#
# Epoch 00009: val_loss improved from 0.00044 to 0.00044, saving model to tmp_checkpoint.h5
# Epoch 10/200
# 120/120 - 1s - loss: 3.4411e-04 - val_loss: 7.3905e-04
#
# Epoch 00010: val_loss did not improve from 0.00044
# Epoch 11/200
# 120/120 - 1s - loss: 4.0369e-04 - val_loss: 4.2587e-04
#
# Epoch 00011: val_loss improved from 0.00044 to 0.00043, saving model to tmp_checkpoint.h5
# Epoch 12/200
# 120/120 - 1s - loss: 3.3941e-04 - val_loss: 5.0054e-04
#
# Epoch 00012: val_loss did not improve from 0.00043
# Epoch 13/200
# 120/120 - 1s - loss: 3.6120e-04 - val_loss: 8.5713e-04
#
# Epoch 00013: val_loss did not improve from 0.00043
# Epoch 14/200
# 120/120 - 1s - loss: 4.0689e-04 - val_loss: 4.6761e-04
#
# Epoch 00014: val_loss did not improve from 0.00043
# Epoch 15/200
# 120/120 - 1s - loss: 2.9370e-04 - val_loss: 3.9429e-04
#
# Epoch 00015: val_loss improved from 0.00043 to 0.00039, saving model to tmp_checkpoint.h5
# Epoch 16/200
# 120/120 - 1s - loss: 4.5518e-04 - val_loss: 4.5029e-04
#
# Epoch 00016: val_loss did not improve from 0.00039
# Epoch 17/200
# 120/120 - 1s - loss: 3.2604e-04 - val_loss: 3.5392e-04
#
# Epoch 00017: val_loss improved from 0.00039 to 0.00035, saving model to tmp_checkpoint.h5
# Epoch 18/200
# 120/120 - 1s - loss: 3.8140e-04 - val_loss: 4.0720e-04
#
# Epoch 00018: val_loss did not improve from 0.00035
# Epoch 19/200
# 120/120 - 1s - loss: 3.0203e-04 - val_loss: 5.5366e-04
#
# Epoch 00019: val_loss did not improve from 0.00035
# Epoch 20/200
# 120/120 - 1s - loss: 3.8945e-04 - val_loss: 4.9850e-04
#
# Epoch 00020: val_loss did not improve from 0.00035
# Epoch 21/200
# 120/120 - 1s - loss: 2.7803e-04 - val_loss: 3.4841e-04
#
# Epoch 00021: val_loss improved from 0.00035 to 0.00035, saving model to tmp_checkpoint.h5
# Epoch 22/200
# 120/120 - 1s - loss: 3.2929e-04 - val_loss: 4.9196e-04
#
# Epoch 00022: val_loss did not improve from 0.00035
# Epoch 23/200
# 120/120 - 1s - loss: 4.0471e-04 - val_loss: 3.6704e-04
#
# Epoch 00023: val_loss did not improve from 0.00035
# Epoch 24/200
# 120/120 - 1s - loss: 2.5004e-04 - val_loss: 2.9021e-04
#
# Epoch 00024: val_loss improved from 0.00035 to 0.00029, saving model to tmp_checkpoint.h5
# Epoch 25/200
# 120/120 - 1s - loss: 2.6742e-04 - val_loss: 3.3689e-04
#
# Epoch 00025: val_loss did not improve from 0.00029
# Epoch 26/200
# 120/120 - 1s - loss: 2.8242e-04 - val_loss: 2.9549e-04
#
# Epoch 00026: val_loss did not improve from 0.00029
# Epoch 27/200
# 120/120 - 1s - loss: 3.8453e-04 - val_loss: 7.7266e-04
#
# Epoch 00027: val_loss did not improve from 0.00029
# Epoch 28/200
# 120/120 - 1s - loss: 3.4722e-04 - val_loss: 2.5577e-04
#
# Epoch 00028: val_loss improved from 0.00029 to 0.00026, saving model to tmp_checkpoint.h5
# Epoch 29/200
# 120/120 - 1s - loss: 2.2411e-04 - val_loss: 2.3841e-04
#
# Epoch 00029: val_loss improved from 0.00026 to 0.00024, saving model to tmp_checkpoint.h5
# Epoch 30/200
# 120/120 - 1s - loss: 2.1405e-04 - val_loss: 2.2492e-04
#
# Epoch 00030: val_loss improved from 0.00024 to 0.00022, saving model to tmp_checkpoint.h5
# Epoch 31/200
# 120/120 - 1s - loss: 2.1082e-04 - val_loss: 3.1001e-04
#
# Epoch 00031: val_loss did not improve from 0.00022
# Epoch 32/200
# 120/120 - 1s - loss: 2.2575e-04 - val_loss: 4.1661e-04
#
# Epoch 00032: val_loss did not improve from 0.00022
# Epoch 33/200
# 120/120 - 1s - loss: 2.2553e-04 - val_loss: 1.9948e-04
#
# Epoch 00033: val_loss improved from 0.00022 to 0.00020, saving model to tmp_checkpoint.h5
# Epoch 34/200
# 120/120 - 1s - loss: 1.8335e-04 - val_loss: 2.2700e-04
#
# Epoch 00034: val_loss did not improve from 0.00020
# Epoch 35/200
# 120/120 - 1s - loss: 1.6671e-04 - val_loss: 2.4284e-04
#
# Epoch 00035: val_loss did not improve from 0.00020
# Epoch 36/200
# 120/120 - 1s - loss: 2.5907e-04 - val_loss: 3.2732e-04
#
# Epoch 00036: val_loss did not improve from 0.00020
# Epoch 37/200
# 120/120 - 1s - loss: 3.0963e-04 - val_loss: 2.1537e-04
#
# Epoch 00037: val_loss did not improve from 0.00020
# Epoch 38/200
# 120/120 - 1s - loss: 1.7668e-04 - val_loss: 2.9086e-04
#
# Epoch 00038: val_loss did not improve from 0.00020

# %%
model.load_weights(filename)
pred = model.predict(test_feature)

# %% [markdown]
# # RMSE 뽑아 내기

# %%
from sklearn.metrics import mean_squared_error
RMSE = mean_squared_error(test_label,pred)**0.5
RMSE
# Out:
# 0.02842585483918172

# %%
plt.figure(figsize=(12, 9))
plt.plot(test_label, label='actual')
plt.plot(pred, label='prediction')
plt.legend()
plt.show()
